# %% [markdown]
# <img src='https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcQ-VfNtOyJbsaxu43Kztf_cv1mgBG6ZIQZEVw&usqp=CAU'>
#
# # Procesamiento de Lenguage Natural
#
# ## Taller #8: Modelado de temas

# %%
import re
import pandas as pd 
from pprint import pprint

from nltk.corpus import stopwords
stopwords = stopwords.words('spanish')

import pyLDAvis.gensim
from gensim.models import LdaModel
from gensim.corpora import Dictionary

import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)
# Out:
# C:\Users\USER\anaconda3\lib\site-packages\scipy\sparse\sparsetools.py:21: DeprecationWarning: `scipy.sparse.sparsetools` is deprecated!
# scipy.sparse.sparsetools is a private module for scipy.sparse, and should not be used.
#   _deprecated()

# %%
# Cargar datos
path = 'desktop/archivos/reviews_vidjew_es.csv'
data = pd.read_csv(path)
data.head()
# Out:
#     review_id          product_id          reviewer_id  stars  \
# 0  es_0825565  product_es_0370490  reviewer_es_0174781      3
# 1  es_0227934  product_es_0354224  reviewer_es_0411613      3
# 2  es_0468601  product_es_0665460  reviewer_es_0348315      1
# 3  es_0814494  product_es_0692692  reviewer_es_0951508      5
# 4  es_0206329  product_es_0728826  reviewer_es_0493255      4
#
#                                          review_body            review_title  \
# 0         Buen. Buena calidad, y buena presentación.                Contenta
# 1  Un producto a perfecto, para salir de casa con...            Versatilidad
# 2  No funciona con Nintendo Switch. No hay forma ...      Decepción absoluta
# 3  Recomendado, los utilizo para pc y no me dan n...  Auriculares Pecham ps4
# 4  El cable funciona bien podria ser un poco mas ...                Perfecto
#
#   language product_category
# 0       es          jewelry
# 1       es      video_games
# 2       es      video_games
# 3       es      video_games
# 4       es      video_games

# %% [markdown]
# ###  `[12 pts]` Punto 1: Hacer pre-procesamiento del texto

# %%
def pre_procesado(texto):
    texto = texto.lower()
    texto = re.sub(r"[\W\d_]+", " ", texto)
    texto = [palabra for palabra in texto.split() if palabra not in stopwords]
    return texto
 
data['Pre-Processed'] = data['review_body'].apply(lambda texto: pre_procesado(texto))
 
data.head()
# Out:
#     review_id          product_id          reviewer_id  stars  \
# 0  es_0825565  product_es_0370490  reviewer_es_0174781      3
# 1  es_0227934  product_es_0354224  reviewer_es_0411613      3
# 2  es_0468601  product_es_0665460  reviewer_es_0348315      1
# 3  es_0814494  product_es_0692692  reviewer_es_0951508      5
# 4  es_0206329  product_es_0728826  reviewer_es_0493255      4
#
#                                          review_body            review_title  \
# 0         Buen. Buena calidad, y buena presentación.                Contenta
# 1  Un producto a perfecto, para salir de casa con...            Versatilidad
# 2  No funciona con Nintendo Switch. No hay forma ...      Decepción absoluta
# 3  Recomendado, los utilizo para pc y no me dan n...  Auriculares Pecham ps4
# 4  El cable funciona bien podria ser un poco mas ...                Perfecto
#
#   language product_category                                      Pre-Processed
# 0       es          jewelry        [buen, buena, calidad, buena, presentación]
# 1       es      video_games  [producto, perfecto, salir, casa, nintendo, sw...
# 2       es      video_games  [funciona, nintendo, switch, forma, emparejarl...
# 3       es      video_games  [recomendado, utilizo, pc, dan, ningún, proble...
# 4       es      video_games  [cable, funciona, bien, podria, ser, mas, larg...

# %% [markdown]
# ###  `[13 pts]` Punto 2: Modelo de LDA

# %%
# Crear una representación de los documentos en forma de diccionario
dictionary = Dictionary(data['Pre-Processed'].values)

# Filtrar palabras muy frecuentes o infrecuentes
dictionary.filter_extremes(no_below=5, no_above=0.5)
 
corpus = [dictionary.doc2bow(text) for text in data['Pre-Processed'].values]

#Train the topic model
model = LdaModel(corpus=corpus, id2word=dictionary, num_topics=5, passes=150)

# %% [markdown]
# ###  `[25 pts]` Punto 3: Visualización de LDA

# %%
lda_display = pyLDAvis.gensim.prepare(model, corpus, dictionary, sort_topics=False)
pyLDAvis.display(lda_display)
# Out:
# <link rel="stylesheet" type="text/css" href="https://cdn.rawgit.com/bmabey/pyLDAvis/files/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el1166429771019369683422258019"></div>
# <script type="text/javascript">
#
# var ldavis_el1166429771019369683422258019_data = {"mdsDat": {"x": [0.03270367881559004, 0.14696608187982033, -0.2227222354422345, -0.04988130845525542, 0.0929337832020797], "y": [-0.1243247391308642, -0.11774770350772946, -0.032196065997956616, 0.07904483209055954, 0.19522367654599065], "topics": [1, 2, 3, 4, 5], "cluster": [1, 1, 1, 1, 1], "Freq": [21.807190268649997, 17.46391999020217, 19.250945807568964, 25.07114775889167, 16.406796174687198]}, "tinfo": {"Term": ["juego", "foto", "bien", "calidad", "perfecto", "buen", "bonito", "regalo", "buena", "bonitos", "mando", "amazon", "ps", "gustado", "entrega", "cumple", "pendientes", "jugar", "pulsera", "precio", "caja", "funciona", "lleg\u00f3", "igual", "plata", "mala", "llegado", "queda", "espa\u00f1ol", "si", "devolver", "cargador", "anillo", "vino", "conectar", "voy", "cabe", "pantalla", "momento", "funcionar", "negro", "perfecto", "llegaron", "funda", "cuello", "buscaba", "piedra", "justo", "contenta", "sale", "quieres", "switch", "dedo", "caja", "much\u00edsimo", "meses", "llego", "transporte", "funciona", "nota", "perfectamente", "queda", "ve", "nintendo", "colgante", "tiempo", "despu\u00e9s", "bonito", "grande", "as\u00ed", "bien", "peque\u00f1o", "env\u00edo", "juego", "si", "solo", "producto", "correcto", "mas", "comprar", "tal", "mando", "lleg\u00f3", "mejor", "dos", "entrega", "espa\u00f1ol", "servicio", "italiano", "presentaci\u00f3n", "entretenido", "primero", "jugando", "prime", "compras", "siempre", "ingles", "espa\u00f1ola", "rapidez", "luces", "opinar", "jugabilidad", "hijo", "saga", "misma", "genial", "amazon", "buen", "va", "rapido", "sistema", "esperando", "juego", "versi\u00f3n", "ingl\u00e9s", "muchas", "paquete", "gran", "llegado", "producto", "gusto", "d\u00eda", "comprar", "viene", "solo", "cosa", "aunque", "precio", "as\u00ed", "si", "recomiendo", "regalo", "r\u00e1pido", "sido", "cumple", "mandos", "sonido", "xbox", "expectativas", "ps", "deja", "cuanto", "pc", "carga", "buenos", "ideal", "horas", "cargar", "unas", "general", "relaci\u00f3n", "materiales", "alta", "vale", "desear", "funci\u00f3n", "one", "ruido", "imposible", "ponen", "mont\u00f3n", "entra", "rato", "cable", "juegos", "caso", "consola", "buena", "jugar", "mando", "verdad", "tener", "original", "calidad", "si", "mas", "precio", "bien", "bastante", "mejor", "solo", "problema", "puede", "ser", "pena", "bonitos", "pendientes", "mala", "quedan", "peque\u00f1os", "roto", "pl\u00e1stico", "ni\u00f1as", "bonitas", "encajan", "perdi\u00f3", "ajustar", "dorado", "ped\u00ed", "negra", "fea", "enviaron", "super", "juegazo", "aspecto", "mujer", "grandes", "enseguida", "plata", "nunca", "ajusta", "dem\u00e1s", "medio", "elegantes", "fina", "cadena", "tampoco", "bien", "lleg\u00f3", "cierre", "d\u00edas", "compre", "tama\u00f1o", "calidad", "demasiado", "pulsera", "precio", "d\u00eda", "puede", "aunque", "producto", "llegado", "ser", "bastante", "si", "mas", "foto", "igual", "collar", "entregado", "pandora", "realidad", "hija", "peor", "decepcionado", "rosa", "ven", "piedras", "deber\u00edan", "tiendas", "certificado", "debido", "rompio", "conjunto", "usado", "art\u00edculo", "visto", "ninguna", "gustado", "color", "peque\u00f1as", "encant\u00f3", "regalo", "s\u00f3lo", "simplemente", "compro", "aparece", "mes", "bonito", "compr\u00e9", "tal", "pedido", "pulsera", "bonita", "tan", "precio", "gusta", "uso", "parece", "encantado", "dan", "mal", "gusto", "vez", "calidad", "producto", "bastante", "d\u00eda", "sido"], "Freq": [117.0, 52.0, 184.0, 144.0, 58.0, 61.0, 63.0, 62.0, 66.0, 38.0, 52.0, 34.0, 29.0, 33.0, 23.0, 24.0, 28.0, 34.0, 37.0, 116.0, 46.0, 34.0, 42.0, 17.0, 34.0, 24.0, 50.0, 35.0, 17.0, 112.0, 10.468365016278561, 10.465702537016476, 8.599326095489928, 8.590277201623726, 8.586415684356776, 7.664468444889112, 7.661098840649799, 7.655485651835998, 19.50945668069426, 6.731370920590308, 6.727997473280467, 52.74174652979111, 5.783434916674247, 12.344301480051591, 4.781003019744124, 4.707773310825 ...
