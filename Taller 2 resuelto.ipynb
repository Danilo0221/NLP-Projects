# %% [markdown]
# # Taller 2

# %% [markdown]
# Xiomy Díaz Morales - Esp. Analítica Estratégica de datos

# %% [markdown]
# ### Punto 1

# %% [markdown]
# #### 1.1 Descomprimir archivo Zip

# %%
import os
from zipfile import ZipFile

# %%
direccion = "Desktop/archivos/poemas.zip"

# %%
#Descomprimir el archivo
with ZipFile(direccion) as archivo:
    archivo.extractall("Desktop/archivos")

# %% [markdown]
# Ver el nombre de los archivos

# %%
for archivo in os.walk('archivos/poemas'):
    print(archivo)
# Out:
# ('archivos/poemas', [], ['A un general (Julio Corta╠üzar).txt', 'Aqui╠ü (Octavio Paz).txt', 'Si╠ündrome (Mario Benedetti).txt'])

# %%
for raiz, dirs, archivos in os.walk('archivos/poemas'):
        for archivo in archivos:
            print(archivo)
# Out:
# A un general (Julio Corta╠üzar).txt
# Aqui╠ü (Octavio Paz).txt
# Si╠ündrome (Mario Benedetti).txt

# %% [markdown]
# #### 1.2 Leer archivos

# %%
# abrir archivo txt en python
with open ("Desktop/archivos/poemas/A un general (Julio Corta╠üzar).txt") as archivo:
    data1 = archivo.read()
    print ("texto1: ",data1)
    print("*"*100)
    print()
    
with open ("Desktop/archivos/poemas/Aqui╠ü (Octavio Paz).txt") as archivo:
    data2 = archivo.read()
    print ("texto2: ",data2) 
    print("*"*100)
    print()
    
with open ("Desktop/archivos/poemas/Si╠ündrome (Mario Benedetti).txt") as archivo:
    data3 = archivo.read()
    print ("texto3: ",data3)  
    print("*"*100)
    print()
# Out:
# texto1:  RegiÃ³n de manos sucias de pinceles sin pelo
#
# de niÃ±os boca abajo de cepillos de dientes
#
# Zona donde la rata se ennoblece
#
# y hay banderas innÃºmeras y cantan himnos
#
# y alguien te prende, hijo de puta,
#
# una medalla sobre el pecho
#
# Y te pudres lo mismo.
# ****************************************************************************************************
#
# texto2:  Mis pasos en esta calle
#
# Resuenan
#
# En otra calle
#
# Donde
#
# Oigo mis pasos
#
# Pasar en esta calle
#
# Donde
#
# SÃ³lo es real la niebla.
# ****************************************************************************************************
#
# texto3:  TodavÃ­a tengo casi todos mis dientes
#
# casi todos mis cabellos y poquÃ­simas canas
#
# puedo hacer y deshacer el amor
#
# trepar una escalera de dos en dos
#
# y correr cuarenta metros detrÃ¡s del Ã³mnibus
#
# o sea que no deberÃ­a sentirme viejo
#
# pero el grave problema es que antes
#
# no me fijaba en estos detalles.
# ****************************************************************************************************

# %% [markdown]
# #### 1.3 ¿Cuál archivo tiene el mayor número de palabras?

# %%
#Para contar palabras en un texto
import re
def countWords(fitxer):
    f = open(fitxer,"r")
    text = f.readlines()
    f.close()
    cont = 0
    for lines in text:
        found = re.findall("([a-z\']+)", lines.strip(), re.I)
        if found:
           cont += len(found)
    if cont > 1:
        return "El archivo tiene %s palabras" % cont
    elif cont == 0:
        return "El archivo esta vacio"
    else:
        return "El archivo tiene %s palabra" % cont

# %%
countWords("Desktop/archivos/poemas/A un general (Julio Corta╠üzar).txt")
# Out:
# 'El archivo tiene 49 palabras'

# %%
countWords("Desktop/archivos/poemas/Aqui╠ü (Octavio Paz).txt")
# Out:
# 'El archivo tiene 24 palabras'

# %%
countWords("Desktop/archivos/poemas/Si╠ündrome (Mario Benedetti).txt")
# Out:
# 'El archivo tiene 57 palabras'

# %% [markdown]
# El archivo con más palabras es Si╠ündrome (Mario Benedetti).txt

# %% [markdown]
# ### Punto 2

# %% [markdown]
# #### 2.1 Web Scraping de 10 biografías en Wikipedia (en búcle)

# %% [markdown]
# #### 2.2 Obtener el encabezado de cada biografía

# %%
import urllib.request

# %%
import bs4 as bs

# %%
links = ["https://es.wikipedia.org/wiki/Carl_Sagan", "https://es.wikipedia.org/wiki/Nikola_Tesla",
        "https://es.wikipedia.org/wiki/Albert_Einstein","https://es.wikipedia.org/wiki/Alan_Turing",
        "https://es.wikipedia.org/wiki/William_Bradford_Shockley","https://es.wikipedia.org/wiki/Ramon_Llull",
        "https://es.wikipedia.org/wiki/Marvin_Minsky","https://es.wikipedia.org/wiki/Allen_Newell",
        "https://es.wikipedia.org/wiki/Herbert_Alexander_Simon","https://es.wikipedia.org/wiki/George_Boole"]

# %%
for scraping in links:
    request = urllib.request.urlopen(scraping)
    source = request.read()
    request.close()
    soup = bs.BeautifulSoup(source,'html.parser') 
    print(soup.find('h1').text)  #Para obtener el encabezado
# Out:
# Carl Sagan
# Nikola Tesla
# Albert Einstein
# Alan Turing
# William Bradford Shockley
# Ramon Llull
# Marvin Minsky
# Allen Newell
# Herbert Alexander Simon
# George Boole

# %% [markdown]
# #### 2.3 Obtener todos los contenidos y etiquetas de título asociados a los links del primer párrafo

# %%
for scraping in links:
    request = urllib.request.urlopen(scraping)
    source = request.read()
    request.close()
    soup = bs.BeautifulSoup(source,'html.parser')
    print(soup.find('h1').text)
    for url in soup.find('p').find_all('a'): #obtener urls de los links del primer párrafo
        print (url)
        print ('Contenido:') #para cada url traer contenido y título
        print (url.contents)
        print ('Título:')
        print(url.get('title'))
    print("*"*100)
    print()
# Out:
# Carl Sagan
# <a href="/wiki/Nueva_York" title="Nueva York">Nueva York</a>
# Contenido:
# ['Nueva York']
# Título:
# Nueva York
# <a href="/wiki/9_de_noviembre" title="9 de noviembre">9 de noviembre</a>
# Contenido:
# ['9 de noviembre']
# Título:
# 9 de noviembre
# <a href="/wiki/1934" title="1934">1934</a>
# Contenido:
# ['1934']
# Título:
# 1934
# <a href="/wiki/Seattle" title="Seattle">Seattle</a>
# Contenido:
# ['Seattle']
# Título:
# Seattle
# <a href="/wiki/20_de_diciembre" title="20 de diciembre">20 de diciembre</a>
# Contenido:
# ['20 de diciembre']
# Título:
# 20 de diciembre
# <a href="/wiki/1996" title="1996">1996</a>
# Contenido:
# ['1996']
# Título:
# 1996
# <a href="/wiki/Astronom%C3%ADa" title="Astronomía">astrónomo</a>
# Contenido:
# ['astrónomo']
# Título:
# Astronomía
# <a href="/wiki/Astrof%C3%ADsica" title="Astrofísica">astrofísico</a>
# Contenido:
# ['astrofísico']
# Título:
# Astrofísica
# <a href="/wiki/Cosmolog%C3%ADa" title="Cosmología">cosmólogo</a>
# Contenido:
# ['cosmólogo']
# Título:
# Cosmología
# <a href="/wiki/Astrobiolog%C3%ADa" title="Astrobiología">astrobiólogo</a>
# Contenido:
# ['astrobiólogo']
# Título:
# Astrobiología
# <a href="/wiki/Nacionalidad_estadounidense" title="Nacionalidad estadounidense">estadounidense</a>
# Contenido:
# ['estadounidense']
# Título:
# Nacionalidad estadounidense
# <a href="/wiki/Universidad_de_Harvard" title="Universidad de Harvard">Universidad de Harvard</a>
# Contenido:
# ['Universidad de Harvard']
# Título:
# Universidad de Harvard
# <a class="mw-redirect" href="/wiki/Universidad_de_Cornell" title="Universidad de Cornell">Universidad de Cornell</a>
# Contenido:
# ['Universidad de Cornell']
# Título:
# Universidad de Cornell
# <a class="new" href="/w/index.php?title=C%C3%A1tedra_David_Duncan_de_Astronom%C3%ADa_y_Ciencias_del_Espacio&amp;action=edit&amp;redlink=1" title="Cátedra David Duncan de Astronomía y Ciencias del Espacio (aún no redactado)">Cátedra David Duncan de Astronomía y Ciencias del Espacio</a>
# Contenido:
# ['Cátedra David Duncan de Astronomía y Ciencias del Espacio']
# Título:
# Cátedra David Duncan de Astronomía y Ciencias del Espacio (aún no redactado)
# <a href="/wiki/1976" title="1976">1976</a>
# Contenido:
# ['1976']
# Título:
# 1976
# <a class="new" href="/w/index.php?title=Laboratorio_de_Estudios_Planetarios&amp;action=edit&amp;redlink=1" title="Laboratorio de Estudios Planetarios (aún no redactado)">Laboratorio de Estudios Planetarios</a>
# Contenido:
# ['Laboratorio de Estudios Planetarios']
# Título:
# Laboratorio de Estudios Planetarios (aún no redactado)
# ****************************************************************************************************
#
# Nikola Tesla
# ****************************************************************************************************
#
# Albert Einstein
# <a href="/wiki/Ayuda:AFI/Alem%C3%A1n" title="Ayuda:AFI/Alemán">/ˈalbɛɐ̯t ˈʔaɪnʃtaɪn/</a>
# Contenido:
# ['/ˈalbɛɐ̯t ˈʔaɪnʃtaɪn/']
# Título:
# Ayuda:AFI/Alemán
# <a href="/wiki/Ulm" title="Ulm">Ulm</a>
# Contenido:
# ['Ulm']
# Título:
# Ulm
# <a href="/wiki/Imperio_alem%C3%A1n" title="Imperio alemán">Imperio alemán</a>
# Contenido:
# ['Imperio alemán']
# Título:
# Imperio alemán
# <a href="/wiki/14_de_marzo" title="14 de marzo">14 de marzo</a>
# Contenido:
# ['14 de marzo']
# Título:
# 14 de marzo
# <a href="/wiki/1879" title="1879">1879</a>
# Contenido:
# ['1879']
# Título:
# 1879
# <a href="/wiki/Princeton_(Nueva_Jersey)" title="Princeton (Nueva Jersey)">Princeton</a>
# Contenido:
# ['Princeton']
# Título:
# Princeton (Nueva Jersey)
# <a href="/wiki/Estados_Unidos" title="Estados Unidos">Estados Unidos</a>
# Contenido:
# ['Estados Unidos']
# Título:
# Estados Unidos
# <a href="/wiki/18_de_abril" title="18 de abril">18 de abril</a>
# Contenido:
# ['18 de abril']
# Título:
# 18 de abril
# <a href="/wiki/1955" title="1955">1955</a>
# Contenido:
# ['1955']
# Título:
# 1955
# <a href="/wiki/F%C3%ADsico" title="Físico">físico</a>
# Contenido:
# ['físico']
# Título:
# Físico
# <a href="/wiki/Imperio_alem%C3%A1n" title="Imperio alemán">alemán</a>
# Contenido:
# ['alemán']
# Título:
# Imperio alemán
# <a href="/wiki/Pueblo_jud%C3%ADo" title="Pueblo judío">judío</a>
# Contenido:
# ['judío']
# Título:
# Pueblo judío
# <a href="/wiki/Suiza" title="Suiza">suizo</a>
# Contenido:
# ['suizo']
# Título:
# Suiza
# <a href="/wiki/Austria" title="Austria">austriaco</a>
# Contenido:
# ['austriaco']
# Título:
# Austria
# <a href="/wiki/Nacionalidad_estadounidense" title="Nacionalidad estadounidense">estadounidense</a>
# Contenido:
# ['estadounidense']
# Título:
# Nacionalidad estadounidense
# <a href="/wiki/Cient%C3%ADfico" title="Científico">científico</a>
# Contenido:
# ['científico']
# Título:
# Científico
# <a href="/wiki/Siglo_XX" title="Siglo XX">siglo XX</a>
# Contenido:
# ['siglo XX']
# Título:
# Siglo XX
# <a href="#cite_note-1"><span class="corchete-llamada">[</span>1<span class="corchete-llamada">]</span></a>
# Contenido:
# [<span class="corchete-llamada">[</span>, '1', <span class="corchete-llamada">]</span>]
# Título:
# None
# <a href="#cite_note-2"><span class="corchete-llamada">[</span>2<span class="corchete-llamada">]</span></a>
# Contenido:
# [<span class="corchete-llamada">[</span>, '2', <span class="corchete-llamada">]</span>]
# Título:
# None
# ****************************************************************************************************
#
# Alan Turing
# <a href="/wiki/Paddington" title="Paddington">Paddington</a>
# Contenido:
# ['Paddington']
# Título:
# Paddington
# <a href="/wiki/Londres" title="Londres">Londres</a>
# Contenido:
# ['Londres']
# Título:
# Londres
# <a href="/wiki/Wilmslow" title="Wilmslow">Wilmslow</a>
# Contenido:
# ['Wilmslow']
# Título:
# Wilmslow
# <a href="/wiki/Cheshire" title="Cheshire">Cheshire</a>
# Contenido:
# ['Cheshire']
# Título:
# Cheshire
# <a href="/wiki/Matem%C3%A1tico" title="Matemático">matemático</a>
# Contenido:
# ['matemático']
# Título:
# Matemático
# <a class="mw-redirect" href="/wiki/L%C3%B3gico" title="Lógico">lógico</a>
# Contenido:
# ['lógico']
# Título:
# Lógico
# <a href="/wiki/Inform%C3%A1tico_te%C3%B3rico" title="Informático teórico">informático teórico</a>
# Contenido:
# ['informático teórico']
# Título:
# Informático teórico
# <a class="mw-redirect" href="/wiki/Cript%C3%B3grafo" title="Criptógrafo">criptógrafo</a>
# Contenido:
# ['criptógrafo']
# Título:
# Criptógrafo
# <a class="mw-redirect" href="/wiki/Fil%C3%B3sofo" title="Filósofo">filósofo</a>
# Contenido:
# ['filósofo']
# Título:
# Filósofo
# <a href="/wiki/Biolog%C3%ADa_te%C3%B3rica" title="Biología teórica">biólogo teórico</a>
# Contenido:
# ['biólogo teórico']
# Título:
# Biología teórica
# <a href="/wiki/Marat%C3%B3n" title="Maratón">maratoniano</a>
# Contenido:
# ['maratoniano']
# Título:
# Maratón
# <a class="mw-redirect" href="/wiki/Ultramaraton" title="Ultramaraton">ultradistancia</a>
# Contenido:
# ['ultradistancia']
# Título:
# Ultramaraton
# <a href="/wiki/Reino_Unido" title="Reino Unido">británico</a>
# Contenido:
# ['británico']
# Título:
# Reino Unido
# <a href="#cite_note-1"><span class="corchete-llamada">[</span>1<span class="corchete-llamada">]</span></a>
# Contenido:
# [<span class="corchete-llamada">[</span>, '1', <span class="corchete-llamada">]</span>]
# Título:
# None
# <a href="#cite_note-2"><span class="corchete-llamada">[</span>2<span class="corchete-llamada">]</span></a>
# Contenido:
# [<span class="corchete-llamada">[</span>, '2', <span class="corchete-llamada">]</span>]
# Título:
# None
# <a href="#cite_note-3"><span class="corchete-llamada">[</span>3<span class="corchete-llamada">]</span></a>
# Contenido:
# [<span class="corchete-llamada">[</span>, '3', <span class="corchete-llamada">]</span>]
# Título:
# None
# <a href="#cite_note-4"><span class="corchete-llamada">[</span>4<span class="corchete-llamada">]</span></a>
# Contenido:
# [<span class="corchete-llamada">[</span>, '4', <span class="corchete-llamada">]</span>]
# Título:
# None
# <a href="#cite_note-5"><span class="corchete-llamada">[</span>5<span class="corchete-llamada">]</span></a>
# Contenido:
# [<span class="corchete-llamada">[</span>, '5', <span class="corchete-llamada">]</span>]
# Título:
# None
# ****************************************************************************************************
#
# William Bradford Shockley
# <a href="/wiki/13_de_febrero" title="13 de febrero">13 de febrero</a>
# Contenido:
# ['13 de febrero']
# Título:
# 13 de febrero
# <a href="/wiki/1910" title="1910">1910</a>
# Contenido:
# ['1910']
# Título:
# 1910
# <a href="/wiki/12_de_agosto" title="12 de agosto">12 de agosto</a>
# Contenido:
# ['12 de agosto']
# Título:
# 12 de agosto
# <a href="/wiki/1989" title="1989">1989</a>
# Contenido:
# ['1989']
# Título:
# 1989
# <a href="/wiki/F%C3%ADsico" title="Físico">físico</a>
# Contenido:
# ['físico']
# Título:
# Físico
# <a href="/wiki/Estados_Unidos" title="Estados Unidos">estadounidense</a>
# Contenido:
# ['estadounidense']
# Título:
# Estados Unidos
# <a href="/wiki/John_Bardeen" title="John Bardeen">John Bardeen</a>
# Contenido:
# ['John Bardeen']
# Título:
# John Bardeen
# <a href="/wiki/Walter_Houser_Brattain" title="Walter Houser Brattain">Walter Houser Brattain</a>
# Contenido:
# ['Walter Houser Brattain']
# Título:
# Walter Houser Brattain
# <a href="/wiki/1956" title="1956">1956</a>
# Contenido:
# ['1956']
# Título:
# 1956
# <a class="mw-redirect" href="/wiki/Semiconductores" title="Semiconductores">semiconductores</a>
# Contenido:
# ['semiconductores']
# Título:
# Semiconductores
# <a href="/wiki/Transistor" title="Transistor">Transistor</a>
# Contenido:
# ['Transistor']
# Título:
# Transistor
# <a href="#cite_note-1"><span class="corchete-llamada">[</span>1<span class="corchete-llamada">]</span></a>
# Contenido:
# [<span class="corchete-llamada">[</span>, '1', <span class="corchete-llamada">]</span>]
# Título:
# None
# ****************************************************************************************************
#
# Ramon Llull
# <a href="/wiki/Mallorca" title="Mallorca">Mallorca</a>
# Contenido:
# ['Mallorca']
# Título:
# Mallorca
# <a href="/wiki/Circa" title="Circa">c.</a>
# Contenido:
# ['c.']
# Título:
# Circa
# <a href="/wiki/1232" title="1232">1232</a>
# Contenido:
# ['1232']
# Título:
# 1232
# <a href="/wiki/1315" title="1315">1315</a>
# Contenido:
# ['1315']
# Título:
# 1315
# <a href="/wiki/1316" title="1316">1316</a>
# Contenido:
# ['1316']
# Título:
# 1316
# <a href="#cite_note-Cuatrecasas-1"><span class="corchete-llamada">[</span>1<span class="corchete-llamada">]</span></a>
# Contenido:
# [<span class="corchete-llamada">[</span>, '1', <span class="corchete-llamada">]</span>]
# Título:
# None
# <a href="#cite_note-Báez_Rubí-2"><span class="corchete-llamada">[</span>2<span class="corchete-llamada">]</span></a>
# Contenido:
# [<span class="corchete-llamada">[</span>, '2', <span class="corchete-llamada">]</span>]
# Título:
# None
# <a href="#cite_note-Galmés-3"><span class="corchete-llamada">[</span>3<span class="corchete-llamada">]</span></a>
# Contenido:
# [<span class="corchete-llamada">[</span>, '3', <span class="corchete-llamada">]</span>]
# Título:
# None
# <a href="#cite_note-Historia-4"><span class="corchete-llamada">[</span>4<span class="corchete-llamada">]</span></a>
# Contenido:
# [<span class="corchete-llamada">[</span>, '4', <span class="corchete-llamada">]</span>]
# Título:
# None
# <a class="mw-redirect" href="/wiki/Idioma_castellano" title="Idioma castellano">castellano</a>
# Contenido:
# ['castellano']
# Título:
# Idioma castellano
# <a href="/wiki/Lat%C3%ADn" title="Latín">latín</a>
# Contenido:
# ['latín']
# Título:
# Latín
# <a href="/wiki/Idioma_%C3%A1rabe" title="Idioma árabe">árabe</a>
# Contenido:
# ['árabe']
# Título:
# Idioma árabe
# <a href="/wiki/Idioma_ingl%C3%A9s" title="Idioma inglés">ingleses</a>
# Contenido:
# ['ingleses']
# Título:
# Idioma inglés
# <a href="/wiki/Idioma_italiano" title="Idioma italiano">italianos</a>
# Contenido:
# ['italianos']
# Título:
# Idioma italiano
# <a href="/wiki/Idioma_franc%C3%A9s" title="Idioma francés">franceses</a>
# Contenido:
# ['franceses']
# Título:
# Idioma francés
# <a href="/wiki/Laico_(religi%C3%B3n)" title="Laico (religión)">laico</a>
# Contenido:
# ['laico']
# Título:
# Laico (religión)
# <a class="mw-redirect" href="/wiki/Franciscano" title="Franciscano">franciscanos</a>
# Contenido:
# ['franciscanos']
# Título:
# Franciscano
# <a class="mw-redirect" href="/wiki/Tercera_orden_de_San_Francisco" title="Tercera orden de San Francisco">Orden Tercera de San Francisco</a>
# Contenido:
# ['Orden Tercera de San Francisco']
# Título:
# Tercera orden de San Francisco
# <a href="/wiki/Filosof%C3%ADa" title="Filosofía">filósofo</a>
# Contenido:
# ['filósofo']
# Título:
# Filosofía
# <a href="/wiki/Poes%C3%ADa" title="Poesía">poeta</a>
# Contenido:
# ['poeta']
# Título:
# Poesía
# <a href="/wiki/Misticismo" title="Misticismo">místico</a>
# Contenido:
# ['místico']
# Título:
# Misticismo
# <a href="/wiki/Teolog%C3%ADa" title="Teología">teólogo</a>
# Contenido:
# ['teólogo']
# Título:
# Teología
# <a href="/wiki/Misionero" title="Misionero">misionero</a>
# Contenido:
# ['misionero']
# Título:
# Misionero
# <a href="/wiki/Reino_de_Mallorca" title="Reino de Mallorca">mallorquín</a>
# Contenido:
# ['mallorquín']
# Título:
# Reino de Mallorca
# <a href="/wiki/Beato" title="Beato">beato</a>
# Contenido:
# ['beato']
# Título:
# Beato
# <a href="#cite_note-beato-5"><span class="corchete-llamada">[</span>5<span class="corchete-llamada">]</span></a>
# Contenido:
# [<span class="corchete-llamada">[</span>, '5', <span class="corchete-llamada">]</span>]
# Título:
# None
# <a href="/wiki/27_de_noviembre" title="27 de noviembre">27 de noviembre</a>
# Contenido:
# ['27 de noviembre']
# Título:
# 27 de noviembre
# ****************************************************************************************************
#
# Marvin Minsky
# <a href="/wiki/Nueva_York" title="Nueva York">Nueva York</a>
# Contenido:
# ['Nueva York']
# Título:
# Nueva York
# <a href="/wiki/Boston" title="Boston">Boston</a>
# Contenido:
# ['Boston']
# Título:
# Boston
# <a href="#cite_note-1"><span class="corchete-llamada">[</span>1<span class="corchete-llamada">]</span></a>
# Contenido:
# [<span class="corchete-llamada">[</span>, '1', <span class="corchete-llamada">]</span>]
# Título:
# None
# <a href="/wiki/Nacionalidad_estadounidense" title="Nacionalidad estadounidense">estadounidense</a>
# Contenido:
# ['estadounidense']
# Título:
# Nacionalidad estadounidense
# <a href="/wiki/Inteligencia_artificial" title="Inteligencia artificial">inteligencia artificial</a>
# Contenido:
# ['inteligencia artificial']
# Título:
# Inteligencia artificial
# <a href="/wiki/Inteligencia_artificial" title="Inteligencia artificial">inteligencia artificial</a>
# Contenido:
# ['inteligencia artificial']
# Título:
# Inteligencia artificial
# ****************************************************************************************************
#
# Allen Newell
# <a href="/wiki/19_de_marzo" title="19 de marzo">19 de marzo</a>
# Contenido:
# ['19 de marzo']
# Título:
# 19 de marzo
# <a href="/wiki/1927" title="1927">1927</a>
# Contenido:
# ['1927']
# Título:
# 1927
# <a href="/wiki/19_de_julio" title="19 de julio">19 de julio</a>
# Contenido:
# ['19 de julio']
# Título:
# 19 de julio
# <a href="/wiki/1992" title="1992">1992</a>
# Contenido:
# ['1992']
# Título:
# 1992
# <a href="/wiki/Inform%C3%A1tica" title="Informática">informática</a>
# Contenido:
# ['informática']
# Título:
# Informática
# <a href="/wiki/Psicolog%C3%ADa_cognitiva" title="Psicología cognitiva">psicología cognitiva</a>
# Contenido:
# ['psicología cognitiva']
# Título:
# Psicología cognitiva
# <a class="mw-redirect" href="/wiki/Carnegie_Mellon" title="Carnegie Mellon">Carnegie Mellon</a>
# Contenido:
# ['Carnegie Mellon']
# Título:
# Carnegie Mellon
# <a class="new" href="/w/index.php?title=Lenguaje_de_procesamiento_de_informaci%C3%B3n&amp;action=edit&amp;redlink=1" title="Lenguaje de procesamiento de información (aún no redactado)">lenguaje de procesamiento de información</a>
# Contenido:
# ['lenguaje de procesamiento de información']
# Título:
# Lenguaje de procesamiento de información (aún no redactado)
# <a class="mw-disambig" href="/wiki/IPL" title="IPL">IPL</a>
# Contenido:
# ['IPL']
# Título:
# IPL
# <a href="/wiki/1956" title="1956">1956</a>
# Contenido:
# ['1956']
# Título:
# 1956
# <a href="/wiki/Inteligencia_artificial" title="Inteligencia artificial">inteligencia artificial</a>
# Contenido:
# ['inteligencia artificial']
# Título:
# Inteligencia artificial
# <a class="new" href="/w/index.php?title=M%C3%A1quina_de_l%C3%B3gica_te%C3%B3rica&amp;action=edit&amp;redlink=1" title="Máquina de lógica teórica (aún no redactado)">máquina de lógica teórica</a>
# Contenido:
# ['máquina de lógica teórica']
# Título:
# Máquina de lógica teórica (aún no redactado)
# <a class="new" href="/w/index.php?title=Resolutor_general_de_problemas&amp;action=edit&amp;redlink=1" title="Resolutor general de problemas (aún no redactado)">resolutor general de problemas</a>
# Contenido:
# ['resolutor general de problemas']
# Título:
# Resolutor general de problemas (aún no redactado)
# <a href="/wiki/1957" title="1957">1957</a>
# Contenido:
# ['1957']
# Título:
# 1957
# <a class="mw-redirect" href="/wiki/Herbert_Simon" title="Herbert Simon">Herbert Simon</a>
# Contenido:
# ['Herbert Simon']
# Título:
# Herbert Simon
# ****************************************************************************************************
#
# Herbert Alexander Simon
# <a href="/wiki/15_de_junio" title="15 de junio">15 de junio</a>
# Contenido:
# ['15 de junio']
# Título:
# 15 de junio
# <a href="/wiki/1916" title="1916">1916</a>
# Contenido:
# ['1916']
# Título:
# 1916
# <a href="/wiki/9_de_febrero" title="9 de febrero">9 de febrero</a>
# Contenido:
# ['9 de febrero']
# Título:
# 9 de febrero
# <a href="/wiki/2001" title="2001">2001</a>
# Contenido:
# ['2001']
# Título:
# 2001
# <a href="/wiki/Economista" title="Economista">economista</a>
# Contenido:
# ['economista']
# Título:
# Economista
# <a class="mw-redirect" href="/wiki/Polit%C3%B3logo" title="Politólogo">politólogo</a>
# Contenido:
# ['politólogo']
# Título:
# Politólogo
# <a href="/wiki/Ciencias_sociales" title="Ciencias sociales">ciencias sociales</a>
# Contenido:
# ['ciencias sociales']
# Título:
# Ciencias sociales
# ****************************************************************************************************
#
# George Boole
# <a href="/wiki/Lincoln_(Lincolnshire)" title="Lincoln (Lincolnshire)">Lincoln</a>
# Contenido:
# ['Lincoln']
# Título:
# Lincoln (Lincolnshire)
# <a href="/wiki/Lincolnshire" title="Lincolnshire">Lincolnshire</a>
# Contenido:
# ['Lincolnshire']
# Título:
# Lincolnshire
# <a href="/wiki/Inglaterra" title="Inglaterra">Inglaterra</a>
# Contenido:
# ['Inglaterra']
# Título:
# Inglaterra
# <a href="/wiki/2_de_noviembre" title="2 de noviembre">2 de noviembre</a>
# Contenido:
# ['2 de noviembre']
# Título:
# 2 de noviembre
# <a href="/wiki/1815" title="1815">1815</a>
# Contenido:
# ['1815']
# Título:
# 1815
# <a class="new" href="/w/index.php?title=Ballintemple&amp;action=edit&amp;redlink=1" title="Ballintemple (aún no redactado)">Ballintemple</a>
# Contenido:
# ['Ballintemple']
# Título:
# Ballintemple (aún no redactado)
# <a href="/wiki/Condado_de_Cork" title="Condado de Cork">Condado de Cork</a>
# Contenido:
# ['Condado de Cork']
# Título:
# Condado de Cork
# <a href="/wiki/Irlanda" title="Irlanda">Irlanda</a>
# Contenido:
# ['Irlanda']
# Título:
# Irlanda
# <a href="/wiki/8_de_diciembre" title="8 de diciembre">8 de diciembre</a>
# Contenido:
# ['8 de diciembre']
# Título:
# 8 de diciembre
# <a href="/wiki/1864" title="1864">1864</a>
# Contenido:
# ['1864']
# Título:
# 1864
# <a href="/wiki/Matem%C3%A1tico" title="Matemático">matemático</a>
# Contenido:
# ['matemático']
# Título:
# Matemático
# <a class="mw-redirect" href="/wiki/L%C3%B3gico" title="Lógico">lógico</a>
# Contenido:
# ['lógico']
# Título:
# Lógico
# <a href="/wiki/Reino_Unido" title="Reino Unido">británico</a>
# Contenido:
# ['británico']
# Título:
# Reino Unido
# ****************************************************************************************************
